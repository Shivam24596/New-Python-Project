# %%
import pandas as pd
import requests as rs

# %%
df = pd.read_csv("Netflix_dataset.csv")
df
# Out:
#            id                            title  release_year  runtime  \
# 0     ts89259               The Queen's Gambit          2020       56
# 1     ts81120                   The Last Dance          2020       50
# 2    ts235758                Never Have I Ever          2020       28
# 3    tm863808               My Octopus Teacher          2020       84
# 4    ts219660              Alice in Borderland          2020       47
# 5    tm847085               The Social Dilemma          2020       94
# 6    ts222333                           Arcane          2021       41
# 7    ts220305                       Squid Game          2021       55
# 8    ts223537                             Maid          2021       54
# 9     ts87242                  Shadow and Bone          2021       52
# 10   ts311985                       Inside Job          2021       28
# 11  tm1038686               Bo Burnham: Inside          2021       87
# ...

# %%
df.head()
# Out:
#          id                title  release_year  runtime  imdb_score  \
# 0   ts89259   The Queen's Gambit          2020       56         8.6
# 1   ts81120       The Last Dance          2020       50         9.1
# 2  ts235758    Never Have I Ever          2020       28         7.8
# 3  tm863808   My Octopus Teacher          2020       84         8.1
# 4  ts219660  Alice in Borderland          2020       47         7.6
#
#    imdb_votes  tmdb_popularity  tmdb_score
# 0      420100             82.7         8.6
# 1      115915             27.7         8.2
# 2       47000             47.8         8.2
# 3       52771             19.3         8.0
# 4       49446             71.0         8.2

# %%
df.describe()
# Out:
#        release_year     runtime  imdb_score     imdb_votes  tmdb_popularity  \
# count     25.000000   25.000000   25.000000      25.000000        25.000000
# mean    2021.200000   61.520000    8.156000   68726.320000        53.328000
# std        0.816497   27.943574    0.499233  115797.761134        78.930394
# min     2020.000000   24.000000    7.600000      83.000000         0.600000
# 25%     2021.000000   47.000000    7.800000    1684.000000         6.400000
# 50%     2021.000000   55.000000    8.000000   42817.000000        20.400000
# 75%     2022.000000   82.000000    8.600000   77885.000000        71.000000
# max     2022.000000  149.000000    9.100000  426967.000000       361.900000
#
#        tmdb_score
# count   25.000000
# mean     7.964000
# std      0.706447
# min      6.200000
# 25%      7.700000
# 50%      8.200000
# 75%      8.200000
# max      9.100000
